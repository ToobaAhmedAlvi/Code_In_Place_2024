# %%
f = open("cswords.txt", "r")

# %%
for line in f:
    print(line)
# Out:
# Karel
#
# For Loop
#
# While Loop
#
# If Statement
#
# Else
#
# Function
#
# Parameter
#
# Return Value
#
# CS106A
#
# Lists
#
# File Reading
#
# Index
#
# Print
#
# Beeper
#
# Main
#
# Input
#
# Turn Right
#
# Khansole Academy
#
# Diagnostic
#
# String
#
# Integer
#
# Float
#
# Boolean
#
# Range
#
# Style
#
# Graphics
#
# Constant
#
# Stanford
#
# Code in Place
#
# Datascience
#
# Good Times
#
# Chris Piech
#
# Mehran Sahami
#
# Burrito
#
# Toaster
#
# Suitcase
#
# URL
#
# Teaching Team
#
# Section Leader
#
# Sections
#
# Scribble
#
# Random Circles
#
# Starter Code
#
# Python
#
# Bright Simons
#
# Variable
#
# For Each
#
# Random

# %%
lines=[]
for values in f:
    #print(values)
    line = values.strip()
    lines.append(line)
print(lines)
# Out:
# Karel
#
# For Loop
#
# While Loop
#
# If Statement
#
# Else
#
# Function
#
# Parameter
#
# Return Value
#
# CS106A
#
# Lists
#
# File Reading
#
# Index
#
# Print
#
# Beeper
#
# Main
#
# Input
#
# Turn Right
#
# Khansole Academy
#
# Diagnostic
#
# String
#
# Integer
#
# Float
#
# Boolean
#
# Range
#
# Style
#
# Graphics
#
# Constant
#
# Stanford
#
# Code in Place
#
# Datascience
#
# Good Times
#
# Chris Piech
#
# Mehran Sahami
#
# Burrito
#
# Toaster
#
# Suitcase
#
# URL
#
# Teaching Team
#
# Section Leader
#
# Sections
#
# Scribble
#
# Random Circles
#
# Starter Code
#
# Python
#
# Bright Simons
#
# Variable
#
# For Each
#
# Random
# ['Karel', 'For Loop', 'While Loop', 'If Statement', 'Else', 'Function', 'Parameter', 'Return Value', 'CS106A', 'Lists', 'File Reading', 'Index', 'Print', 'Beeper', 'Main', 'Input', 'Turn Right', 'Khansole Academy', 'Diagnostic', 'String', 'Integer', 'Float', 'Boolean', 'Range', 'Style', 'Graphics', 'Constant', 'Stanford', 'Code in Place', 'Datascience', 'Good Times', 'Chris Piech', 'Mehran Sahami', 'Burrito', 'Toaster', 'Suitcase', 'URL', 'Teaching Team', 'Section Leader', 'Sections', 'Scribble', 'Random Circles', 'Starter Code', 'Python', 'Bright Simons', 'Variable', 'For Each', 'Random']

# %%
lines
# Out:
# []

# %%
lines = []
for line in f:
    # removes whitespace characters (\n) from the start and end of the line
    line = line.strip() 
    # if the line was only whitespace characters, skip it 
    if line != "":
        lines.append(line)
    print(lines)
