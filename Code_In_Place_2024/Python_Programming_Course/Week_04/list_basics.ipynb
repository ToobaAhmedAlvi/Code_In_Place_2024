# %%
x= [6,8,4,9,2]
print(x)
type(x)
# Out:
# [6, 8, 4, 9, 2]
# list

# %% [markdown]
# ### SORTING AN ARRAY

# %%
sorted(x)
#x.sort()
#print(x)
# Out:
# [2, 4, 6, 8, 9]
# [6, 8, 4, 9, 2]

# %% [markdown]
# ### REVERSING AN ARRAY

# %%
#reversed(x)
#x.reverse()
print(x)
